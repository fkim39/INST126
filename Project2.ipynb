# %%
import random
words = ["WHDSPQZ","XHO","TTDBFRT","QQJYF","ENQD","DNPK","CNTR","EHWHOD","TSVMOHOF","XNOCFQGTM"]
import string

def correct_word(words):
    word = random.choice(words) # randomly chooses something from the words list
    return word

def decrypt(ciphertext):
    plaintext = ""
    i=0
    for i in range (0,len(ciphertext)):
        if i % 2 == 0:
            plain_ascii = ciphertext[i]
            cipher_ascii = ord(plain_ascii) - 1
            plaintext = plaintext + str(chr(cipher_ascii))
        if i % 2 == 1:
            plain_ascii = ciphertext[i]
            cipher_ascii = ord(plain_ascii) + 1
            plaintext = plaintext + str(chr(cipher_ascii))
    
    return plaintext
    


def hangman():
    word = correct_word(words)
    word_letters = set(word)  # letters in the word
    alphabet = set(string.ascii_uppercase)
    used_letters = set() # the letters the user has guessed
    
    lives = 10
    
    #gaining user input
    while len(word_letters) > 0 and lives > 0:
        print('You have', lives, 'lives left and you have used these letters: ', ' '.join(used_letters))
         
        # what current word is (ie W - R D)
        word_list = [letter if letter in used_letters else '-' for letter in word]
        print('Current word: ',' '.join(word_list))

        user_letter = input('Guess a letter: ').upper()
        if user_letter in alphabet - used_letters:
            used_letters.add(user_letter)
            if user_letter in word_letters:
                word_letters.remove(user_letter)
            
            else:
                lives = lives - 1  # takes away a life if wrong
                print('That letter is not in the word')
    
        elif user_letter in used_letters:
            print('You already used that letter... Try again.')
        
        else:
            print('Invalid Character... Try again.')
            
    
    # Results here when len(word_letters) == 0 OR when lives == 0        
    if lives == 0:
        print('You died, the word was', word)
    else:            
        print('You guessed the word', word, 'The decoded message is', decrypt(word), '!')

        
            

hangman()
# Out:
# You have 10 lives left and you have used these letters:
# Current word:  - - - -
# Guess a letter: f
# That letter is not in the word
# You have 9 lives left and you have used these letters:  F
# Current word:  - - - -
# Guess a letter: q
# That letter is not in the word
# You have 8 lives left and you have used these letters:  Q F
# Current word:  - - - -
# Guess a letter: we
# Invalid Character... Try again.
# You have 8 lives left and you have used these letters:  Q F
# Current word:  - - - -
# Guess a letter: e
# That letter is not in the word
# You have 7 lives left and you have used these letters:  Q F E
# Current word:  - - - -
# Guess a letter: e
# You already used that letter... Try again.
# You have 7 lives left and you have used these letters:  Q F E
# Current word:  - - - -
# Guess a letter: r
# You have 7 lives left and you have used these letters:  R Q F E
# Current word:  - - - R
# Guess a letter: t
# You have 7 lives left and you have used these letters:  R F E T Q
# Current word:  - - T R
# Guess a letter: y
# That letter is not in the word
# You have 6 lives left and you have used these letters:  R F E T Y Q
# Current word:  - - T R
# Guess a letter:
# Invalid Character... Try again.
# You have 6 lives left and you have used these letters:  R F E T Y Q
# Current word:  - - T R
# Guess a letter: u
# That letter is not in the word
# You have 5 lives left and you have used these letters:  R F E T U Y Q
# Current word:  - - T R
# Guess a letter: i
# That letter is not in the word
# You have 4 lives left and you have used these letters:  R I F E T U Y Q
# Current word:  - - T R
# Guess a letter: b
# That letter is not in the word
# You have 3 lives left and you have used these letters:  R I F E B T U Y Q
# Current word:  - - T R
# Guess a letter: n
# You have 3 lives left and you have used these letters:  R I F N E B T U Y Q
# Current word:  - N T R
# Guess a letter: g
# That letter is not in the word
# You have 2 lives left and you have used these letters:  R I F G N E B T U Y Q
# Current word:  - N T R
# Guess a letter: r
# You already used that letter... Try again.
# You have 2 lives left and you have used these letters:  R I F G N E B T U Y Q
# Current word:  - N T R
# Guess a letter: t
# You already used that letter... Try again.
# You have 2 lives left and you have used these letters:  R I F G N E B T U Y Q
# Current word:  - N T R
# Guess a letter: h
# That letter is not in the word
# You have 1 lives left and you have used these letters:  R H I F G N E B T U Y Q
# Current word:  - N T R
# Guess a letter: j
# That letter is not in the word
# You died, the word was CNTR
